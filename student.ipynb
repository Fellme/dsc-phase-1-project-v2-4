# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Morgan Fell
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name: Mark Bourbor
# * Blog post URL:

# %% [markdown]
# # Business Understanding

# %% [markdown]
# # Data Understanding

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3

# %%
conn = sqlite3.connect('im.db.sqlite')

# %%
import zipfile
with zipfile.ZipFile('zippedData/im.db.zip', 'r') as zip_ref:
    zip_ref.extractall('zippedData')

# %%
from pandasql import sqldf 
pysqldf = lambda q: sqldf(q, globals())

# %%
from os.path import exists
file_exists = exists('zippedData/im.db')
if file_exists:
    print('Successfully downloaded and unzipped the file. Please proceed.')
else:
    print('''
          The database file was not found.  
          Please ensure that the database file has been downloaded
          and unzipped into the 'zippedData' folder located
          in the folder that this Jupyter notebook resides.
          ''')
# Out:
# Successfully downloaded and unzipped the file. Please proceed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
conn = sqlite3.connect('zippedData/im.db')
query = """  SELECT * FROM sqlite_master  """
tables = pd.read_sql(query, conn)
tables
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
q2 = """SELECT * FROM movie_ratings"""
imdb_movie_ratings = pd.read_sql(q2, conn)
imdb_movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
q3 = """SELECT * FROM movie_basics"""
imdb_movie_basics = pd.read_sql(q3, conn)
imdb_movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
q5 = """SELECT * FROM directors"""
imdb_directors = pd.read_sql(q5, conn)
imdb_directors.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
q6 = """SELECT * FROM persons"""
imdb_persons = pd.read_sql(q6, conn)
imdb_persons.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
q7 = """SELECT * FROM writers"""
imdb_writers = pd.read_sql(q7, conn)
imdb_writers.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
tmdb_df_og = pd.read_csv('./zippedData/tmdb.movies.csv.gz', index_col = 0, 
                      parse_dates=['release_date'])
tmdb_df_og
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 9 columns]

# %%
tmdb_df_og.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  datetime64[ns]
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
df_budgets = pd.read_csv('./zippedData/tn.movie_budgets.csv.gz', index_col = 0,
                     parse_dates=['release_date'])
df_budgets
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ..          ...                                          ...
# 78   2018-12-31                                       Red 11
# 79   1999-04-02                                    Following
# 80   2005-07-13                Return to the Land of Wonders
# 81   2015-09-29                         A Plague So Pleasant
# 82   2005-08-05                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747
# ..               ...            ...             ...
# 78            $7,000             $0              $0
# 79            $6,000        $48,482        $240,495
# 80            $5,000         $1,338          $1,338
# 81            $1,400             $0              $0
# 82            $1,100       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
df_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 271.0+ KB

# %%
df_mojo = pd.read_csv('./zippedData/bom.movie_gross.csv.gz', index_col = 0)
df_mojo.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
df_mojo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %%
df_mojo.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### IMDB Cleaning

# %%
#Calculating the average votes and maximum number of votes to create a filter point
avg_votes = pd.read_sql("""SELECT AVG(numvotes) AS avg_votes, MAX(numvotes) AS max_votes FROM movie_ratings;""", conn)
avg_votes
# Out:
#      avg_votes  max_votes
# 0  3523.662167    1841066

# %%
#Joining movie_ratings with movie_basics using the limits of needing at least 3500 votes and an average rating of 7.5 based on the values from above
q4 = """
    SELECT * 
    FROM movie_ratings
    JOIN movie_basics USING(movie_id)
    WHERE numvotes >= 3500 AND averagerating >= 7.5 
    ORDER BY averagerating DESC
""" 
df_imdb = pd.read_sql(q4, conn)

#The original_title column is unnecessary given the primary_title
df_imdb.drop(['original_title'], axis=1)
# Out:
#       movie_id  averagerating  numvotes                      primary_title  \
# 0    tt7131622            9.7      5600  Once Upon a Time ... in Hollywood
# 1    tt5963218            9.5      6509                      Aloko Udapadi
# 2    tt7738784            9.4      9629                            Peranbu
# 3    tt5813916            9.3    100568                    The Mountain II
# 4    tt5354160            9.3     18470                           Aynabaji
# ..         ...            ...       ...                                ...
# 726  tt1438298            7.5     15402                          Guzaarish
# 727  tt1798243            7.5     16303                         Rudderless
# 728  tt3808342            7.5     39232                        Son of Saul
# 729  tt4425200            7.5    290053               John Wick: Chapter 2
# 730  tt2532528            7.5      8700                         Dirty Wars
#
#      start_year  runtime_minutes                   genres
# 0          2019            159.0             Comedy,Drama
# 1          2017            113.0            Drama,History
# 2          2018            147.0                    Drama
# 3          2016            135.0         Action,Drama,War
# 4          2016            147.0   Crime,Mystery,Thriller
# ..          ...              ...                      ...
# 726        2010            126.0                    Drama
# 727        2014            105.0       Comedy,Drama,Music
# 728        2015            107.0                Drama,War
# 729        2017            122.0    Action,Crime,Thriller
# 730        2013             87.0  Crime,Documentary,Drama
#
# [731 rows x 7 columns]

# %%
#Genres were split at the comma with 
df_imdb['genres'] = df_imdb['genres'].apply(lambda x: x.split(','))
df_imdb = df_imdb.explode('genres')
df_imdb
# Out:
#       movie_id  averagerating  numvotes                      primary_title  \
# 0    tt7131622            9.7      5600  Once Upon a Time ... in Hollywood
# 0    tt7131622            9.7      5600  Once Upon a Time ... in Hollywood
# 1    tt5963218            9.5      6509                      Aloko Udapadi
# 1    tt5963218            9.5      6509                      Aloko Udapadi
# 2    tt7738784            9.4      9629                            Peranbu
# ..         ...            ...       ...                                ...
# 729  tt4425200            7.5    290053               John Wick: Chapter 2
# 729  tt4425200            7.5    290053               John Wick: Chapter 2
# 730  tt2532528            7.5      8700                         Dirty Wars
# 730  tt2532528            7.5      8700                         Dirty Wars
# 730  tt2532528            7.5      8700                         Dirty Wars
#
#                         original_title  start_year  runtime_minutes  \
# 0    Once Upon a Time ... in Hollywood        2019            159.0
# 0    Once Upon a Time ... in Hollywood        2019            159.0
# 1                        Aloko Udapadi        2017            113.0
# 1                        Aloko Udapadi        2017            113.0
# 2                              Peranbu        2018            147.0
# ..                                 ...         ...              ...
# 729               John Wick: Chapter 2        2017            122.0
# 729               John Wick: Chapter 2        2017            122.0
# 730                         Dirty Wars        2013             87.0
# 730                         Dirty Wars        2013             87.0
# 730                         Dirty Wars        2013             87.0
#
#           genres
# 0         Comedy
# 0          Drama
# 1          Drama
# 1        History
# 2          Drama
# ..           ...
# 729        Crime
# 729     Thriller
# 730        Crime
# 730  Documentary
# 730        Drama
#
# [1749 rows x 8 columns]

# %%
df_imdb.genres.value_counts()
# Out:
# Drama          457
# Action         160
# Comedy         149
# Documentary    136
# Biography      106
# Crime          101
# Adventure       99
# Thriller        95
# Romance         80
# Animation       57
# History         54
# Mystery         51
# Music           38
# Sci-Fi          33
# Fantasy         31
# Sport           25
# Family          25
# War             24
# Horror          13
# Musical          7
# News             5
# Western          3
# Name: genres, dtype: int64

# %% [markdown]
# ### The Numbers Cleaning

# %% [markdown]
# Null values were dropped
#
# Domestic gross was also dropped so that we can focus on how a movie did worldwide

# %%
#Null values were dropped from the data table
df_budgets.dropna()
#We want to know how well the movie performed in every country it was released in so we will drop the domestic_gross
df_budgets_clean = df_budgets.drop('domestic_gross', axis=1)
df_budgets_clean
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ..          ...                                          ...
# 78   2018-12-31                                       Red 11
# 79   1999-04-02                                    Following
# 80   2005-07-13                Return to the Land of Wonders
# 81   2015-09-29                         A Plague So Pleasant
# 82   2005-08-05                            My Date With Drew
#
#    production_budget worldwide_gross
# id
# 1       $425,000,000  $2,776,345,279
# 2       $410,600,000  $1,045,663,875
# 3       $350,000,000    $149,762,350
# 4       $330,600,000  $1,403,013,963
# 5       $317,000,000  $1,316,721,747
# ..               ...             ...
# 78            $7,000              $0
# 79            $6,000        $240,495
# 80            $5,000          $1,338
# 81            $1,400              $0
# 82            $1,100        $181,041
#
# [5782 rows x 4 columns]

# %%
#A function is used to clean the money columns production_budget and worldwide_gross. The function will return values in a numeric form without the comma or dollar sign. Since this is a general function it can be used again if needed
def convert_monies(df, column):
    df[column] = pd.to_numeric(df[column].str.replace(",", "").str.replace("$", ""))
    
    return df

convert_monies(df_budgets_clean, 'production_budget')
convert_monies(df_budgets_clean, 'worldwide_gross')
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ..          ...                                          ...
# 78   2018-12-31                                       Red 11
# 79   1999-04-02                                    Following
# 80   2005-07-13                Return to the Land of Wonders
# 81   2015-09-29                         A Plague So Pleasant
# 82   2005-08-05                            My Date With Drew
#
#     production_budget  worldwide_gross
# id
# 1           425000000       2776345279
# 2           410600000       1045663875
# 3           350000000        149762350
# 4           330600000       1403013963
# 5           317000000       1316721747
# ..                ...              ...
# 78               7000                0
# 79               6000           240495
# 80               5000             1338
# 81               1400                0
# 82               1100           181041
#
# [5782 rows x 4 columns]

# %%
#Any zero dollar values were removed from the worldwide_gross
df_tn_clean = df_budgets_clean[df_budgets_clean["worldwide_gross"] != 0]
df_tn_clean
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ..          ...                                          ...
# 76   2006-05-26                                       Cavite
# 77   2004-12-31                              The Mongol King
# 79   1999-04-02                                    Following
# 80   2005-07-13                Return to the Land of Wonders
# 82   2005-08-05                            My Date With Drew
#
#     production_budget  worldwide_gross
# id
# 1           425000000       2776345279
# 2           410600000       1045663875
# 3           350000000        149762350
# 4           330600000       1403013963
# 5           317000000       1316721747
# ..                ...              ...
# 76               7000            71644
# 77               7000              900
# 79               6000           240495
# 80               5000             1338
# 82               1100           181041
#
# [5415 rows x 4 columns]

# %%
#The release_date had to be converted from the nano-second [ns] based format in order to filter movies only from the last 10 years
df_tn_clean = df_tn_clean[(df_tn_clean['release_date'] >= '2012-01-01')]
df_tn_clean
# Out:
#    release_date                                 movie  production_budget  \
# id
# 3    2019-06-07                          Dark Phoenix          350000000
# 4    2015-05-01               Avengers: Age of Ultron          330600000
# 5    2017-12-15     Star Wars Ep. VIII: The Last Jedi          317000000
# 6    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 7    2018-04-27                Avengers: Infinity War          300000000
# ..          ...                                   ...                ...
# 20   2015-07-31                              Counting              50000
# 38   2016-03-18                                Krisha              30000
# 45   2017-01-27                                 Emily              27000
# 49   2015-09-01                                Exeter              25000
# 73   2012-01-13                             Newlyweds               9000
#
#     worldwide_gross
# id
# 3         149762350
# 4        1403013963
# 5        1316721747
# 6        2053311220
# 7        2048134200
# ..              ...
# 20             8374
# 38           144822
# 45             3547
# 49           489792
# 73             4584
#
# [1423 rows x 4 columns]

# %%
#The worldwide_gross column is sorted from highest to lowest with a limit of 500 to give us the top 500 performing movies over the last 10 years
df_tn_filtered = df_tn_clean.sort_values(by='worldwide_gross', ascending=False)[:500]
df_tn_filtered
# Out:
#    release_date                                 movie  production_budget  \
# id
# 6    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 7    2018-04-27                Avengers: Infinity War          300000000
# 34   2015-06-12                        Jurassic World          215000000
# 67   2015-04-03                             Furious 7          190000000
# 27   2012-05-04                          The Avengers          225000000
# ..          ...                                   ...                ...
# 63   2018-10-12       Goosebumps 2: Haunted Halloween           35000000
# 21   2018-08-10                        BlacKkKlansman           15000000
# 77   2016-03-25            My Big Fat Greek Wedding 2           18000000
# 34   2015-11-06                             Spotlight           20000000
# 23   2016-08-19                               Ben-Hur           95000000
#
#     worldwide_gross
# id
# 6        2053311220
# 7        2048134200
# 34       1648854864
# 67       1518722794
# 27       1517935897
# ..              ...
# 63         93291478
# 21         93017335
# 77         92096558
# 34         92088460
# 23         91669648
#
# [500 rows x 4 columns]

# %%
#The return on invest was calculated by dividing the value in worldwide_gross by the production_budget. This is then converted to a percent by multipling by 100.
df_tn_filtered["RoI"] = ((df_tn_filtered['worldwide_gross'] - df_tn_filtered['production_budget'])/df_tn_filtered['production_budget']) * 100
df_tn_filtered
# Out:
#    release_date                                 movie  production_budget  \
# id
# 6    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 7    2018-04-27                Avengers: Infinity War          300000000
# 34   2015-06-12                        Jurassic World          215000000
# 67   2015-04-03                             Furious 7          190000000
# 27   2012-05-04                          The Avengers          225000000
# ..          ...                                   ...                ...
# 63   2018-10-12       Goosebumps 2: Haunted Halloween           35000000
# 21   2018-08-10                        BlacKkKlansman           15000000
# 77   2016-03-25            My Big Fat Greek Wedding 2           18000000
# 34   2015-11-06                             Spotlight           20000000
# 23   2016-08-19                               Ben-Hur           95000000
#
#     worldwide_gross         RoI
# id
# 6        2053311220  571.016739
# 7        2048134200  582.711400
# 34       1648854864  666.909239
# 67       1518722794  699.327786
# 27       1517935897  574.638176
# ..              ...         ...
# 63         93291478  166.547080
# 21         93017335  520.115567
# 77         92096558  411.647544
# 34         92088460  360.442300
# 23         91669648   -3.505634
#
# [500 rows x 5 columns]

# %%
#A new column showing only the month is generated to visualize the best time of year to release a movie
df_tn_filtered['mm'] = pd.to_datetime(df_tn_filtered['release_date']).dt.strftime('%m')
df_tn_filtered
# Out:
#    release_date                                 movie  production_budget  \
# id
# 6    2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 7    2018-04-27                Avengers: Infinity War          300000000
# 34   2015-06-12                        Jurassic World          215000000
# 67   2015-04-03                             Furious 7          190000000
# 27   2012-05-04                          The Avengers          225000000
# ..          ...                                   ...                ...
# 63   2018-10-12       Goosebumps 2: Haunted Halloween           35000000
# 21   2018-08-10                        BlacKkKlansman           15000000
# 77   2016-03-25            My Big Fat Greek Wedding 2           18000000
# 34   2015-11-06                             Spotlight           20000000
# 23   2016-08-19                               Ben-Hur           95000000
#
#     worldwide_gross         RoI  mm
# id
# 6        2053311220  571.016739  12
# 7        2048134200  582.711400  04
# 34       1648854864  666.909239  06
# 67       1518722794  699.327786  04
# 27       1517935897  574.638176  05
# ..              ...         ...  ..
# 63         93291478  166.547080  10
# 21         93017335  520.115567  08
# 77         92096558  411.647544  03
# 34         92088460  360.442300  11
# 23         91669648   -3.505634  08
#
# [500 rows x 6 columns]

# %%
#Our imdb data is merged with The Numbers data to make it easier for visualization
mass_df = df_tn_filtered.join(df_imdb.set_index('original_title'), on='movie', how='inner')
mass_df
# Out:
#    release_date                   movie  production_budget  worldwide_gross  \
# id
# 7    2018-04-27  Avengers: Infinity War          300000000       2048134200
# 7    2018-04-27  Avengers: Infinity War          300000000       2048134200
# 7    2018-04-27  Avengers: Infinity War          300000000       2048134200
# 27   2012-05-04            The Avengers          225000000       1517935897
# 27   2012-05-04            The Avengers          225000000       1517935897
# ..          ...                     ...                ...              ...
# 21   2018-08-10          BlacKkKlansman           15000000         93017335
# 21   2018-08-10          BlacKkKlansman           15000000         93017335
# 21   2018-08-10          BlacKkKlansman           15000000         93017335
# 34   2015-11-06               Spotlight           20000000         92088460
# 34   2015-11-06               Spotlight           20000000         92088460
#
#            RoI  mm   movie_id  averagerating  numvotes  \
# id
# 7   582.711400  04  tt4154756            8.5    670926
# 7   582.711400  04  tt4154756            8.5    670926
# 7   582.711400  04  tt4154756            8.5    670926
# 27  574.638176  05  tt0848228            8.1   1183655
# 27  574.638176  05  tt0848228            8.1   1183655
# ..         ...  ..        ...            ...       ...
# 21  520.115567  08  tt7349662            7.5    149005
# 21  520.115567  08  tt7349662            7.5    149005
# 21  520.115567  08  tt7349662            7.5    149005
# 34  360.442300  11  tt1895587            8.1    365110
# 34  360.442300  11  tt1895587            8.1    365110
#
#              primary_title  start_year  runtime_minutes     genres
# id
# 7   Avengers: Infinity War        2018            149.0     Action
# 7   Avengers: Infinity War        2018            149.0  Adventure
# 7   Avengers: Infinity War        2018            149.0     Sci-Fi
# 27            The Avengers        2012            143.0     Action
# 27            The Avengers        2012            143.0  Adventure
# ..                     ...         ...              ...        ...
# 21          BlacKkKlansman        2018            135.0  Biography
# 21          BlacKkKlansman        2018            135.0      Crime
# 21          BlacKkKlansman        2018            135.0      Drama
# 34               Spotlight        2015            129.0      Crime
# 34               Spotlight        2015            129.0      Drama
#
# [257 rows x 13 columns]

# %%
#The table is sorted from highest to lowest return on invest (RoI)
mass_df = mass_df.sort_values(by='RoI', ascending=False)
mass_df
# Out:
#    release_date              movie  production_budget  worldwide_gross  \
# id
# 49   2017-02-24            Get Out            5000000        255367951
# 49   2017-02-24            Get Out            5000000        255367951
# 49   2017-02-24            Get Out            5000000        255367951
# 56   2016-12-21             Dangal            9500000        294654618
# 56   2016-12-21             Dangal            9500000        294654618
# ..          ...                ...                ...              ...
# 95   2014-06-06   Edge of Tomorrow          178000000        370541256
# 95   2014-06-06   Edge of Tomorrow          178000000        370541256
# 80   2017-10-06  Blade Runner 2049          185000000        259357408
# 80   2017-10-06  Blade Runner 2049          185000000        259357408
# 80   2017-10-06  Blade Runner 2049          185000000        259357408
#
#             RoI  mm   movie_id  averagerating  numvotes      primary_title  \
# id
# 49  5007.359020  02  tt5052448            7.7    400474            Get Out
# 49  5007.359020  02  tt5052448            7.7    400474            Get Out
# 49  5007.359020  02  tt5052448            7.7    400474            Get Out
# 56  3001.627558  12  tt5074352            8.5    123638             Dangal
# 56  3001.627558  12  tt5074352            8.5    123638             Dangal
# ..          ...  ..        ...            ...       ...                ...
# 95   108.169245  06  tt1631867            7.9    546284   Edge of Tomorrow
# 95   108.169245  06  tt1631867            7.9    546284   Edge of Tomorrow
# 80    40.193194  10  tt1856101            8.0    376241  Blade Runner 2049
# 80    40.193194  10  tt1856101            8.0    376241  Blade Runner 2049
# 80    40.193194  10  tt1856101            8.0    376241  Blade Runner 2049
#
#     start_year  runtime_minutes    genres
# id
# 49        2017            104.0  Thriller
# 49        2017            104.0   Mystery
# 49        2017            104.0    Horror
# 56        2016            161.0    Action
# 56        2016            161.0     Drama
# ..         ...              ...       ...
# 95        2014            113.0    Action
# 95        2014            113.0    Sci-Fi
# 80        2017            164.0    Sci-Fi
# 80        2017            164.0   Mystery
# 80        2017            164.0     Drama
#
# [257 rows x 13 columns]

# %%
#Checks to see if music and musical need to be added together
filtered_df = mass_df[(mass_df['genres'] == 'Music') | (mass_df['genres'] == 'Musical')]
filtered_df
# Out:
#    release_date                 movie  production_budget  worldwide_gross  \
# id
# 92   2016-12-09            La La Land           20000000        426351163
# 84   2018-11-02     Bohemian Rhapsody           55000000        894985342
# 25   2017-12-20  The Greatest Showman           84000000        386665550
# 71   2019-05-31             Rocketman           41000000        108642725
#
#             RoI  mm   movie_id  averagerating  numvotes         primary_title  \
# id
# 92  2031.755815  12  tt3783958            8.0    436070            La La Land
# 84  1527.246076  11  tt1727824            8.0    345466     Bohemian Rhapsody
# 25   360.316131  12  tt1485796            7.6    199663  The Greatest Showman
# 71   164.982256  05  tt2066051            7.7     24266             Rocketman
#
#     start_year  runtime_minutes   genres
# id
# 92        2016            128.0    Music
# 84        2018            134.0    Music
# 25        2017            105.0  Musical
# 71        2019            121.0    Music

# %%
#provides the average production budget for each genre
df_genre_budget = mass_df.groupby("genres")["production_budget"].mean()
df_genre_budget
# Out:
# genres
# Action       1.412500e+08
# Adventure    1.610769e+08
# Animation    1.512727e+08
# Biography    3.904000e+07
# Comedy       8.890000e+07
# Crime        4.000000e+07
# Drama        5.419231e+07
# Family       1.350000e+08
# Fantasy      1.870000e+08
# History      4.542857e+07
# Horror       1.400000e+07
# Music        3.866667e+07
# Musical      8.400000e+07
# Mystery      6.085714e+07
# Romance      1.600000e+07
# Sci-Fi       1.603684e+08
# Sport        3.400000e+07
# Thriller     8.255000e+07
# War          8.000000e+07
# Western      1.000000e+08
# Name: production_budget, dtype: float64

# %%
#value_counts allows us more analytics when trying to decide the genre whose RoI is best represented.
genre_value_counts = mass_df.genres.value_counts()
genre_value_counts.mean()
# Out:
# 12.85

# %%
#Given the average number of movies in a genre is 12.85 a filter can be use to only include movies who have at least 12 movies taken into consideration for their roi and production budget.
genre_value = genre_value_counts[mass_df.genres.value_counts() >=12]
genre_value
# Out:
# Drama        52
# Adventure    39
# Action       38
# Biography    25
# Comedy       20
# Sci-Fi       19
# Name: genres, dtype: int64

# %%
#Our mass dataframe is filtered down to only include the genres from above
allowed_genres = ['Drama', 'Sci-fi', 'Action', 'Adventure', 'Comedy', 'Biography']
filtered_mass = mass_df[mass_df['genres'].isin(allowed_genres)]
filtered_mass
# Out:
#    release_date                   movie  production_budget  worldwide_gross  \
# id
# 56   2016-12-21                  Dangal            9500000        294654618
# 56   2016-12-21                  Dangal            9500000        294654618
# 56   2016-12-21                  Dangal            9500000        294654618
# 43   2014-06-06  The Fault in Our Stars           12000000        307166834
# 92   2016-12-09              La La Land           20000000        426351163
# ..          ...                     ...                ...              ...
# 33   2015-12-25       The Hateful Eight           62000000        147864886
# 24   2019-02-14     Alita: Battle Angel          170000000        402976036
# 24   2019-02-14     Alita: Battle Angel          170000000        402976036
# 95   2014-06-06        Edge of Tomorrow          178000000        370541256
# 80   2017-10-06       Blade Runner 2049          185000000        259357408
#
#             RoI  mm   movie_id  averagerating  numvotes  \
# id
# 56  3001.627558  12  tt5074352            8.5    123638
# 56  3001.627558  12  tt5074352            8.5    123638
# 56  3001.627558  12  tt5074352            8.5    123638
# 43  2459.723617  06  tt2582846            7.7    315135
# 92  2031.755815  12  tt3783958            8.0    436070
# ..          ...  ..        ...            ...       ...
# 33   138.491752  12  tt3460252            7.8    434966
# 24   137.044727  02  tt0437086            7.5     88207
# 24   137.044727  02  tt0437086            7.5     88207
# 95   108.169245  06  tt1631867            7.9    546284
# 80    40.193194  10  tt1856101            8.0    376241
#
#              primary_title  start_year  runtime_minutes     genres
# id
# 56                  Dangal        2016            161.0     Action
# 56                  Dangal        2016            161.0      Drama
# 56                  Dangal        2016            161.0  Biography
# 43  The Fault in Our Stars        2014            126.0      Drama
# 92              La La Land        2016            128.0     Comedy
# ..                     ...         ...              ...        ...
# 33       The Hateful Eight        2015            168.0      Drama
# 24     Alita: Battle Angel        2019            122.0     Action
# 24     Alita: Battle Angel        2019            122.0  Adventure
# 95        Edge of Tomorrow        2014            113.0     Action
# 80       Blade Runner 2049        2017            164.0      Drama
#
# [174 rows x 13 columns]

# %%
#The production budget of only the allowed genres is calculated
df_genre_budget = filtered_mass.groupby("genres")["production_budget"].mean()
df_genre_budget
# Out:
# genres
# Action       1.412500e+08
# Adventure    1.610769e+08
# Biography    3.904000e+07
# Comedy       8.890000e+07
# Drama        5.419231e+07
# Name: production_budget, dtype: float64

# %%
#Going back to the larger dataset, the number of movies whose rating is at least 7.5 with at least 3500 votes released each month is calculated
monthly_counts = mass_df['mm'].value_counts()
monthly_counts
# Out:
# 11    70
# 12    37
# 10    29
# 05    21
# 07    20
# 06    19
# 02    18
# 04    14
# 03    12
# 08     9
# 09     8
# Name: mm, dtype: int64

# %% [markdown]
# ### Boxoffice Mojo Cleaning

# %%
#The conversation function is reused to fix the foreign_gross column from an object datatype to a numeric 
convert_monies(df_mojo, 'foreign_gross')
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                              foreign_gross  year
# title
# Toy Story 3                                    652000000.0  2010
# Alice in Wonderland (2010)                     691300000.0  2010
# Harry Potter and the Deathly Hallows Part 1    664300000.0  2010
# Inception                                      535700000.0  2010
# Shrek Forever After                            513900000.0  2010
# ...                                                    ...   ...
# The Quake                                              NaN  2018
# Edward II (2018 re-release)                            NaN  2018
# El Pacto                                               NaN  2018
# The Swan                                               NaN  2018
# An Actor Prepares                                      NaN  2018
#
# [3387 rows x 4 columns]

# %%
df_mojo.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.037000e+03  3387.000000
# mean     2.874585e+07   7.487281e+07  2013.958075
# std      6.698250e+07   1.374106e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.700000e+06  2012.000000
# 50%      1.400000e+06   1.870000e+07  2014.000000
# 75%      2.790000e+07   7.490000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %%
#To find how well the movie performed worldwide, the sum of both gross columns is placed into a new column, total_profit
df_mojo["total_profit"] = df_mojo['domestic_gross'] + df_mojo['foreign_gross']
df_mojo
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                              foreign_gross  year  total_profit
# title
# Toy Story 3                                    652000000.0  2010  1.067000e+09
# Alice in Wonderland (2010)                     691300000.0  2010  1.025500e+09
# Harry Potter and the Deathly Hallows Part 1    664300000.0  2010  9.603000e+08
# Inception                                      535700000.0  2010  8.283000e+08
# Shrek Forever After                            513900000.0  2010  7.526000e+08
# ...                                                    ...   ...           ...
# The Quake                                              NaN  2018           NaN
# Edward II (2018 re-release)                            NaN  2018           NaN
# El Pacto                                               NaN  2018           NaN
# The Swan                                               NaN  2018           NaN
# An Actor Prepares                                      NaN  2018           NaN
#
# [3387 rows x 5 columns]

# %%
#Any null values were dropped to make our data precise
df_mojo.dropna()
# Out:
#                                                          studio  \
# title
# Toy Story 3                                                  BV
# Alice in Wonderland (2010)                                   BV
# Harry Potter and the Deathly Hallows Part 1                  WB
# Inception                                                    WB
# Shrek Forever After                                        P/DW
# ...                                                         ...
# I Still See You                                             LGF
# The Catcher Was a Spy                                       IFC
# Time Freak                                           Grindstone
# Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# Antonio Lopez 1970: Sex Fashion & Disco                      FM
#
#                                                    domestic_gross  \
# title
# Toy Story 3                                           415000000.0
# Alice in Wonderland (2010)                            334200000.0
# Harry Potter and the Deathly Hallows Part 1           296000000.0
# Inception                                             292600000.0
# Shrek Forever After                                   238700000.0
# ...                                                           ...
# I Still See You                                            1400.0
# The Catcher Was a Spy                                    725000.0
# Time Freak                                                10000.0
# Reign of Judges: Title of Liberty - Concept Short         93200.0
# Antonio Lopez 1970: Sex Fashion & Disco                   43200.0
#
#                                                    foreign_gross  year  \
# title
# Toy Story 3                                          652000000.0  2010
# Alice in Wonderland (2010)                           691300000.0  2010
# Harry Potter and the Deathly Hallows Part 1          664300000.0  2010
# Inception                                            535700000.0  2010
# Shrek Forever After                                  513900000.0  2010
# ...                                                          ...   ...
# I Still See You                                        1500000.0  2018
# The Catcher Was a Spy                                   229000.0  2018
# Time Freak                                              256000.0  2018
# Reign of Judges: Title of Liberty - Concept Short         5200.0  2018
# Antonio Lopez 1970: Sex Fashion & Disco                  30000.0  2018
#
#                                                    total_profit
# title
# Toy Story 3                                        1.067000e+09
# Alice in Wonderland (2010)                         1.025500e+09
# Harry Potter and the Deathly Hallows Part 1        9.603000e+08
# Inception                                          8.283000e+08
# Shrek Forever After                                7.526000e+08
# ...                                                         ...
# I Still See You                                    1.501400e+06
# The Catcher Was a Spy                              9.540000e+05
# Time Freak                                         2.660000e+05
# Reign of Judges: Title of Liberty - Concept Short  9.840000e+04
# Antonio Lopez 1970: Sex Fashion & Disco            7.320000e+04
#
# [2007 rows x 5 columns]

# %%
#The total_profit column will be filtered from highest to lowest

df_mojo_filtered = df_mojo.sort_values(by='total_profit', ascending=False)
df_mojo_filtered
# Out:
#                                                  studio  domestic_gross  \
# title
# Marvel's The Avengers                                BV     623400000.0
# Avengers: Age of Ultron                              BV     459000000.0
# Black Panther                                        BV     700100000.0
# Harry Potter and the Deathly Hallows Part 2          WB     381000000.0
# Star Wars: The Last Jedi                             BV     620200000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                              foreign_gross  year  total_profit
# title
# Marvel's The Avengers                          895500000.0  2012  1.518900e+09
# Avengers: Age of Ultron                        946400000.0  2015  1.405400e+09
# Black Panther                                  646900000.0  2018  1.347000e+09
# Harry Potter and the Deathly Hallows Part 2    960500000.0  2011  1.341500e+09
# Star Wars: The Last Jedi                       712400000.0  2017  1.332600e+09
# ...                                                    ...   ...           ...
# The Quake                                              NaN  2018           NaN
# Edward II (2018 re-release)                            NaN  2018           NaN
# El Pacto                                               NaN  2018           NaN
# The Swan                                               NaN  2018           NaN
# An Actor Prepares                                      NaN  2018           NaN
#
# [3387 rows x 5 columns]

# %%
#To be consistent we will trim the data down to only the top 500 movies of the last 10 years and a domestic_gross above the average, which $29million

df_mojo_filtered = df_mojo_filtered[(df_mojo_filtered['year'] >= 2012)][:500]
df_mojo_filtered = df_mojo_filtered[(df_mojo_filtered['domestic_gross'] >= 29000000)]
df_mojo_filtered.dropna()
df_mojo_filtered
# Out:
#                                studio  domestic_gross  foreign_gross  year  \
# title
# Marvel's The Avengers              BV     623400000.0    895500000.0  2012
# Avengers: Age of Ultron            BV     459000000.0    946400000.0  2015
# Black Panther                      BV     700100000.0    646900000.0  2018
# Star Wars: The Last Jedi           BV     620200000.0    712400000.0  2017
# Jurassic World: Fallen Kingdom   Uni.     417700000.0    891800000.0  2018
# ...                               ...             ...            ...   ...
# Evil Dead (2013)                 TriS      54200000.0     43300000.0  2013
# Safe Haven                      Rela.      71300000.0     26200000.0  2013
# Blue Jasmine                      SPC      33400000.0     64099999.0  2013
# The Shack                        LG/S      57400000.0     39600000.0  2017
# Contraband                       Uni.      66500000.0     29700000.0  2012
#
#                                 total_profit
# title
# Marvel's The Avengers           1.518900e+09
# Avengers: Age of Ultron         1.405400e+09
# Black Panther                   1.347000e+09
# Star Wars: The Last Jedi        1.332600e+09
# Jurassic World: Fallen Kingdom  1.309500e+09
# ...                                      ...
# Evil Dead (2013)                9.750000e+07
# Safe Haven                      9.750000e+07
# Blue Jasmine                    9.750000e+07
# The Shack                       9.700000e+07
# Contraband                      9.620000e+07
#
# [447 rows x 5 columns]

# %%
studio_profits = df_mojo_filtered.groupby("studio")["total_profit"].mean()
studio_profits
# Out:
# studio
# BV          6.386911e+08
# CBS         1.310500e+08
# FD          1.660500e+08
# Focus       1.299429e+08
# Fox         3.565324e+08
# FoxS        1.595167e+08
# LG/S        2.485312e+08
# LGF         3.492923e+08
# MGM         2.140000e+08
# ORF         1.096000e+08
# P/DW        5.269000e+08
# Par.        3.203550e+08
# Rela.       1.303000e+08
# SGem        1.883250e+08
# SPC         9.750000e+07
# STX         1.714500e+08
# Sony        3.163961e+08
# Studio 8    9.820000e+07
# TriS        1.776800e+08
# Uni.        3.110825e+08
# W/Dim.      2.681000e+08
# WB          3.594086e+08
# WB (NL)     3.589043e+08
# Wein.       2.097143e+08
# Name: total_profit, dtype: float64

# %%
#This function is used to match unknown studios to titles in order to further research the abbreviation provided 
df_mojo_filtered.loc[df_mojo_filtered['studio'] == 'x']
# Out:
# Empty DataFrame
# Columns: [studio, domestic_gross, foreign_gross, year, total_profit]
# Index: []

# %%
#Fox and FoxS both represent Fox Studios, so the .replace function will be used to replace any FoxS with Fox to condense those averages into one. A value_counts() is used to ensure the function worked.
df_mojo_filtered['studio'] = df_mojo_filtered['studio'].str.replace('FoxS','Fox')
df_mojo_filtered['studio'] = df_mojo_filtered['studio'].str.replace('LG/S','LGF')
df_mojo_filtered['studio'] = df_mojo_filtered['studio'].str.replace('P/DW','Uni.')
df_mojo_filtered.studio.value_counts()
# Out:
# Uni.        76
# Fox         74
# WB          58
# BV          56
# Sony        51
# Par.        40
# LGF         29
# WB (NL)     23
# Wein.        7
# Focus        7
# TriS         5
# SGem         4
# STX          4
# Rela.        3
# ORF          2
# FD           2
# CBS          2
# Studio 8     1
# W/Dim.       1
# SPC          1
# MGM          1
# Name: studio, dtype: int64

# %%
studio_profits = df_mojo_filtered.groupby("studio")["total_profit"].mean()
studio_profits
# Out:
# studio
# BV          6.386911e+08
# CBS         1.310500e+08
# FD          1.660500e+08
# Focus       1.299429e+08
# Fox         3.405581e+08
# LGF         2.937000e+08
# MGM         2.140000e+08
# ORF         1.096000e+08
# Par.        3.203550e+08
# Rela.       1.303000e+08
# SGem        1.883250e+08
# SPC         9.750000e+07
# STX         1.714500e+08
# Sony        3.163961e+08
# Studio 8    9.820000e+07
# TriS        1.776800e+08
# Uni.        3.167619e+08
# W/Dim.      2.681000e+08
# WB          3.594086e+08
# WB (NL)     3.589043e+08
# Wein.       2.097143e+08
# Name: total_profit, dtype: float64

# %% [markdown]
# ### TMDB Cleaning

# %% [markdown]
# The genres keys were accessed from : https://www.themoviedb.org/talk/5daf6eb0ae36680011d7e6ee

# %%
#Creating a backward key to switch out the numbers with the actual genre
backwards_key = {
'Action' : '28',
'Adventure' : '12',
'Animation' : '16',
'Comedy' : '35',
'Crime' : '80',
'Documentary' : '99',
'Drama' : '18',
'Family' : '10751',
'Fantasy' : '14',
'History' : '36',
'Horror' : '27',
'Music' : '10402',
'Mystery' : '9648',
'Romance' : '10749',
'Science Fiction' : '878',
'TV Movie' : '10770',
'Thriller' : '53',
'War' : '10752',
'Western' : '37'
}

genre_key = {v: k for k, v in backwards_key.items()}

# %%
#Lambda function is used to remove the brackets 
tmdb_df_og['genre_ids'] = tmdb_df_og['genre_ids'].apply(lambda x: x.replace('[','').replace(']','')) 

tmdb_df_og.head()
# Out:
#            genre_ids     id original_language  \
# 0      12, 14, 10751  12444                en
# 1  14, 12, 16, 10751  10191                en
# 2        12, 28, 878  10138                en
# 3      16, 35, 10751    862                en
# 4        28, 878, 12  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#The same lambda function from the imdb data was used to separate the genre numbers into different rows
tmdb_df_og['genre_ids'] = tmdb_df_og['genre_ids'].apply(lambda x: x.split(','))
tmdb_df_og = tmdb_df_og.explode('genre_ids')

tmdb_df_og
# Out:
#       genre_ids      id original_language  \
# 0            12   12444                en
# 0            14   12444                en
# 0         10751   12444                en
# 1            14   10191                en
# 1            12   10191                en
# ...         ...     ...               ...
# 26515     10751  366854                en
# 26515        12  366854                en
# 26515        28  366854                en
# 26516        53  309885                en
# 26516        27  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 1                          How to Train Your Dragon      28.734   2010-03-26
# ...                                             ...         ...          ...
# 26515                                  Trailer Made       0.600   2018-06-22
# 26515                                  Trailer Made       0.600   2018-06-22
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 1                          How to Train Your Dragon           7.7        7610
# ...                                             ...           ...         ...
# 26515                                  Trailer Made           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
# 26516                                    The Church           0.0           1
#
# [47834 rows x 9 columns]

# %%
#Extra whitespace is removed 
tmdb_df_og['genre_ids'] = tmdb_df_og['genre_ids'].str.replace('\W', '', regex=True)
tmdb_df_og.head()
# Out:
#   genre_ids     id original_language  \
# 0        12  12444                en
# 0        14  12444                en
# 0     10751  12444                en
# 1        14  10191                en
# 1        12  10191                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 1                      How to Train Your Dragon      28.734   2010-03-26
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 1                      How to Train Your Dragon           7.7        7610

# %%
#The genre ids were switched to text using the backward keys
tmdb_df_og["genre_ids"].replace(genre_key, inplace=True)
tmdb_df_og.head()
# Out:
#    genre_ids     id original_language  \
# 0  Adventure  12444                en
# 0    Fantasy  12444                en
# 0     Family  12444                en
# 1    Fantasy  10191                en
# 1  Adventure  10191                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 1                      How to Train Your Dragon      28.734   2010-03-26
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 1                      How to Train Your Dragon           7.7        7610

# %%
#A breakdown of the data helps provide parameters to begin filtering
tmdb_df_og.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   47834.000000  47834.000000  47834.000000  47834.000000
# mean   287024.114918      3.945417      5.940837    302.524188
# std    155845.657840      5.177258      1.764381   1245.109977
# min        27.000000      0.600000      0.000000      1.000000
# 25%    140595.000000      0.659250      5.000000      2.000000
# 50%    301297.000000      1.779000      6.000000      8.000000
# 75%    413764.750000      5.726500      7.000000     53.000000
# max    608444.000000     80.773000     10.000000  22186.000000

# %%
#Voting averages should not fall below the average of 5.9 with a max of 10
tmdb_filtered = tmdb_df_og[tmdb_df_og['vote_average'].between(5.9, 10)]
tmdb_filtered.head()
# Out:
#    genre_ids     id original_language  \
# 0  Adventure  12444                en
# 0    Fantasy  12444                en
# 0     Family  12444                en
# 1    Fantasy  10191                en
# 1  Adventure  10191                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 1                      How to Train Your Dragon      28.734   2010-03-26
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 1                      How to Train Your Dragon           7.7        7610

# %%
#Checking if .between worked
tmdb_filtered.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   26774.000000  26774.000000  26774.000000  26774.000000
# mean   297547.344999      4.655863      7.111295    473.177486
# std    158606.518890      6.123820      1.105063   1608.812363
# min        62.000000      0.600000      5.900000      1.000000
# 25%    153568.250000      0.648000      6.300000      2.000000
# 50%    320434.000000      1.887000      6.900000     10.000000
# 75%    426279.250000      6.934000      7.600000    103.000000
# max    608079.000000     80.773000     10.000000  22186.000000

# %%
#Consistent filtering of only movies from the last 10 years
tmdb_dated = tmdb_filtered = tmdb_filtered[tmdb_filtered['release_date'] >=
                          pd.Timestamp(2012, 1, 1)]
tmdb_dated.head()
# Out:
#      genre_ids      id original_language          original_title  popularity  \
# 258      Drama   39356                en                     Boy       7.759
# 258     Comedy   39356                en                     Boy       7.759
# 1537     Drama  182026                en         Stranger Things       0.802
# 2506    Horror   22970                en  The Cabin in the Woods      15.336
# 2506    Comedy   22970                en  The Cabin in the Woods      15.336
#
#      release_date                   title  vote_average  vote_count
# 258    2012-03-02                     Boy           7.5         149
# 258    2012-03-02                     Boy           7.5         149
# 1537   2013-04-05         Stranger Things           8.0          14
# 2506   2012-04-12  The Cabin in the Woods           6.5        4185
# 2506   2012-04-12  The Cabin in the Woods           6.5        4185

# %%
#Filtering to only include movies with a vote count greater than or equal to the average from above
tmdb_dated = tmdb_dated[(tmdb_dated['vote_count'] >= 463)]
tmdb_dated.head()
# Out:
#      genre_ids     id original_language          original_title  popularity  \
# 2506    Horror  22970                en  The Cabin in the Woods      15.336
# 2506    Comedy  22970                en  The Cabin in the Woods      15.336
# 2506  Thriller  22970                en  The Cabin in the Woods      15.336
# 2543     Drama  75174                en                The Grey      12.942
# 2543  Thriller  75174                en                The Grey      12.942
#
#      release_date                   title  vote_average  vote_count
# 2506   2012-04-12  The Cabin in the Woods           6.5        4185
# 2506   2012-04-12  The Cabin in the Woods           6.5        4185
# 2506   2012-04-12  The Cabin in the Woods           6.5        4185
# 2543   2012-01-27                The Grey           6.5        2280
# 2543   2012-01-27                The Grey           6.5        2280

# %%
#Only allowing movies released in English 
tmdb_lang = tmdb_dated[(tmdb_dated['original_language'] == 'en')]
tmdb_lang.original_language.unique()
# Out:
# array(['en'], dtype=object)

# %%
#Checking if filters worked
tmdb_dated.describe()
# Out:
#                   id   popularity  vote_average    vote_count
# count    3001.000000  3001.000000   3001.000000   3001.000000
# mean   253854.786071    16.124477      6.815328   3104.096634
# std    124609.051823     8.656191      0.611935   3252.211555
# min       189.000000     0.600000      5.900000    464.000000
# 25%    140420.000000    10.445000      6.300000    852.000000
# 50%    270487.000000    13.802000      6.700000   1764.000000
# 75%    345009.000000    18.978000      7.300000   4086.000000
# max    569547.000000    80.773000      8.600000  20175.000000

# %%
#Finding the popularity of each genre based on the voting average
genre_pop = tmdb_lang.groupby("genre_ids")["vote_average"].mean()
genre_pop
# Out:
# genre_ids
# Action             6.658029
# Adventure          6.824299
# Animation          7.042553
# Comedy             6.748750
# Crime              6.688050
# Documentary        7.820000
# Drama              6.927119
# Family             6.921368
# Fantasy            6.740476
# History            7.104918
# Horror             6.447059
# Music              7.043478
# Mystery            6.593519
# Romance            6.897902
# Science Fiction    6.755629
# TV Movie           6.720000
# Thriller           6.571429
# War                6.996774
# Western            7.060000
# Name: vote_average, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
#Calculating and organizing data being used for bar graph
genre_roi = filtered_mass.groupby("genres")["RoI"].mean()
genre_names = genre_roi.index
genre_values = genre_roi.values

# %%
#Creating dual-y graph to depict RoI of each genre with the average original budget 
fig, ax1 = plt.subplots(figsize=(25, 12))
ax2 = ax1.twinx()

ax1.bar(genre_names, genre_values, color="gold", edgecolor="black", alpha=0.9, width=1.0)
ax2.plot(df_genre_budget, color="purple", lw=4)

ax1.set_xlabel("Genre (at least 12 movies contributing)")
ax1.set_ylabel("RoI(%)", fontsize=14)
ax1.tick_params(axis="y")


ax2.set_ylabel("Production Budget (Hundred Million Dollars)", fontsize=14)
ax2.tick_params(axis="y")


fig.suptitle("Genre Return on Invest with Original Production Budget", fontsize=25);

# %%
#The labels for average studio profit from BoxOffice Mojo
studio_profits_names = studio_profits.index
studio_profits_values = studio_profits.values

#Creating horizontal bar graph
fig, ax = plt.subplots(figsize=(20,20))

ax.barh(studio_profits.index,studio_profits.values, color='green', edgecolor='black')
ax.set_xlabel('Average Profits (Hundred Million Dollars)', fontsize=18)
ax.set_ylabel('Studio', fontsize=18)
ax.set_title("Average Profit of Studios", fontsize=25)


plt.show()

# %%
# Get the labels for the unique months and the value counts for each month
labels = monthly_counts.index
data = monthly_counts.values

# Create the bar graph
fig, ax = plt.subplots(figsize=(20,10))

ax.bar(monthly_counts.index,monthly_counts.values, color='red', edgecolor='black')
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Number of Movies', fontsize=14)
ax.set_title('Number of Movies Released per Month with a Rating of 7.5 or Higher', fontsize=25)

plt.show()

# %%
# Get the labels for the unique months and the value counts for each month
labels = genre_pop.index
data = genre_pop.values

# Create the bar graph
fig, ax = plt.subplots(figsize=(25,12))

ax.bar(genre_pop.index,genre_pop.values, color='cyan', edgecolor='black')
ax.set_xlabel('Genres', fontsize=14)
ax.set_ylabel('Average Popularity Vote (0-10 Scale)', fontsize=14)
ax.set_title('Average Genre Popularity from TMDB', fontsize=25)


plt.show()

# %%
#Seaborn provides an easier method of creating heatmaps when coupled with matplotlib
import seaborn as sns

#Figure resized to better read
plt.figure(figsize=(20,10))

# Create a pivot table with genres as the index, runtime_minutes as the columns, and averagerating as the values
pivot_table = mass_df.pivot_table(index='genres', columns='runtime_minutes', values='averagerating')

# Use the heatmap function from seaborn to create the heatmap
sns.heatmap(pivot_table, cmap='magma_r')

# Add a title and axis labels
plt.title('Average Rating by Genre and Runtime', fontsize=25)
plt.xlabel('Runtime (minutes)', fontsize=14)
plt.ylabel('Genre', fontsize=14)

# Show the plot
plt.show()
